# %%
import re

# %%
test = [
    '2015 Volkswagen Jetta TDI SE 1.4L ELECTRIC/GAS L4  Standard 5 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2L DIESEL L4 ',
    '2015 Volkswagen Jetta GLI SE 2.0L L4 GAS Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta S 1.4L ELECTRIC/GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Standard 6',
    '2015 Volkswagen Jetta Comfortline TDI 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Standard 6',
    '2015 Volkswagen Jetta TDI S 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Highline TDI 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2L DIESEL L4 ',
    '2015 Volkswagen Jetta SE 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 2L DIESEL L4  Standard 6',
    '2015 Volkswagen Jetta TDI SEL 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta S 2.0L L4 GAS Automatic 6',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Standard 6',
    '2015 Volkswagen Jetta TDI SEL 1.4L ELECTRIC/GAS L4  Standard 5 Sedan (4 Door)',
    '2015 Volkswagen Jetta Comfortline TDI 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Trendline TDI 2.0L L4 DIESEL Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI S 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Comfortline 1.8L L4 GAS Standard 5 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 1.8L GAS L4  Standard 5 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2L DIESEL L4 ',
    '2015 Volkswagen Jetta SE 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 1.4L ELECTRIC/GAS L4  Standard 5 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta GLI 2L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Comfortline TDI 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta S 2.0L L4 GAS Standard 5 Sedan (4 Door)',
    '2015 Volkswagen Jetta Comfortline TDI 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2.0L L4 DIESEL Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 1.8L L4 GAS Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2.0L L4 DIESEL Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Trendline 2L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Jetta TDI SE 2L DIESEL L4 ',
    '2015 Volkswagen Jetta SE 1.8L L4 GAS Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Sport 1.8L L4 GAS Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2.0L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Highline TDI 2.0L L4 DIESEL Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta S 2.0L L4 GAS Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Jetta TDI 2.0L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Sport 1.8L GAS L4  Standard 5 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI SEL 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI SE 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SEL 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 1.8L L4 GAS Standard 5 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2.0L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Highline TDI 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta GLI SE 2L GAS L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Comfortline TDI 2.0L L4 DIESEL Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta GLI SEL 2L GAS L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta S 2L GAS L4  Automatic 6',
    '2015 Volkswagen Jetta Sport GAS L4 6A FWD',
    '2015 Volkswagen Jetta TDI S 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Trendline + ',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI S 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta GLI SE 2L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI SE 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Jetta TDI SEL 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI SE 2L DIESEL L4 ',
    '2015 Volkswagen Jetta SE 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Standard 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Sport 1.8L GAS L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SE 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SEL 2L DIESEL L4 ',
    '2015 Volkswagen Jetta Sport 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta GLI 2L GAS L4  Standard 6',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta SEL 1.8L GAS L4  Automatic 6',
    '2015 Volkswagen Jetta TDI S 2L DIESEL L4  Standard 5',
    '2015 Volkswagen Jetta SE 1.8L GAS L4  Automatic 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta GLI 1.4L ELECTRIC/GAS L4  Automatic Dual Clutch 7 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI SE 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta Comfortline 1.4L ELECTRIC/GAS L4  Automatic Dual Clutch 7 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI 2.0L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2.0L DIESEL L4 ',
    '2015 Volkswagen Jetta TDI SEL 1.4L ELECTRIC/GAS L4  Standard 5 Sedan (4 Door)',
    '2015 Volkswagen Jetta Comfortline TDI 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI 2L DIESEL L4  Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta Trendline TDI 2.0L L4 DIESEL Automatic Dual Clutch 6 Sedan (4 Door)',
    '2015 Volkswagen Jetta TDI S 2.0L L4 DIESEL Standard 6 Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L L4 GAS Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic EX ',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX ',
    '2015 Honda Civic Si 2.4L L4 GAS Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Standard 5 Coupe (2 Door)',
    '2015 Honda Civic LX 1.8L L4 GAS Standard 5 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L L4 GAS Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic LX 1.8L CNG L4  Standard 5 Sedan (4 Door)',
    '2015 Honda Civic SE 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic EX-L 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Touring 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX-L ',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Coupe (2 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L L4 GAS Standard 6',
    '2015 Honda Civic EX-L 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic LX 1.8L GAS L4  Automatic CVT Coupe (2 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Coupe (2 Door)',
    '2015 Honda Civic EX 1.8L L4 GAS Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L L4 GAS Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Standard 5 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Standard 5 Coupe (2 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic LX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic LX GAS V4 Automatic 5',
    '2015 Honda Civic EX-L 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Coupe (2 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Hybrid 1.5L ELECTRIC/GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic EX-L 1.8L GAS L4  Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Coupe (2 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Coupe (2 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Coupe (2 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Coupe (2 Door)',
    '2015 Honda Civic EX-L 2.4L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic LX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic EX-L 1.8L GAS L4  Automatic CVT Coupe (2 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Standard 5 Coupe (2 Door)',
    '2015 Honda Civic EX-L 1.5L ELECTRIC/GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX ',
    '2015 Honda Civic LX 1.8L GAS L4  Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Coupe (2 Door)',
    '2015 Honda Civic Si 2.4L L4 GAS Standard 6',
    '2015 Honda Civic EX-L 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic LX 1.8L GAS L4  Automatic CVT Coupe (2 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Coupe (2 Door)',
    '2015 Honda Civic EX 1.8L L4 GAS Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L L4 GAS Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Standard 5 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Standard 5 Coupe (2 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic LX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic LX GAS V4 Automatic 5',
    '2015 Honda Civic EX-L 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Coupe (2 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L L4 GAS Standard 6',
    '2015 Honda Civic EX-L 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic LX 1.8L GAS L4  Automatic CVT Coupe (2 Door)',
    '2015 Honda Civic Si 2.4L GAS L4  Standard 6 Coupe (2 Door)',
    '2015 Honda Civic EX 1.8L L4 GAS Automatic CVT Sedan (4 Door)',
    '2015 Honda Civic Si 2.4L L4 GAS Standard 6 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Standard 5 Sedan (4 Door)',
    '2015 Honda Civic EX 1.8L GAS L4  Automatic CVT Sedan (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf R 2L GAS L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S ',
    '2015 Volkswagen Golf Comfortline 1.8L GAS L4 ',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Standard 6 ',
    '2015 Volkswagen Golf R 2.0L L4 GAS Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Automatic 6',
    '2015 Volkswagen Golf TDI S 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Golf TDI SE 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Golf TDI S 2.0L DIESEL L4 ',
    '2015 Volkswagen Golf Sportwagen TDI Hatchback (4 Door)',
    '2015 Volkswagen Golf GTD DIESEL H4',
    '2015 Volkswagen Golf TDI SEL 2.0L L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L DIESEL L4  Automatic Dual Clutch 6 ',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Standard 6',
    '2015 Volkswagen Golf TDI SE 2.0L L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI Hatchback (4 Door)',
    '2015 Volkswagen Golf SE 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI 2L DIESEL L4  Standard 6',
    '2015 Volkswagen Golf TDI SE 2.0L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf S 1.8L L4 GAS Standard 5 Hatchback (2 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Comfortline 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen Hatchback (4 Door)',
    '2015 Volkswagen Golf R 2.0L L4 GAS Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf R 2L GAS L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf R 2.0L L4 GAS Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf S 1.8L GAS L4  Standard 5 Hatchback (4 Door)',
    '2015 Volkswagen Golf Comfortline TDI 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Trendline 1.8L L4 GAS Standard 5 Hatchback (2 Door)',
    '2015 Volkswagen Golf Comfortline 1.8L L4 GAS Standard 5 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf S 1.8L GAS L4 ',
    '2015 Volkswagen Golf S 1.4L GAS L4  Standard 5 Hatchback (2 Door)',
    '2015 Volkswagen Golf S 1.8L GAS L4  Standard 5 Hatchback (2 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 1.8L GAS L4 ',
    '2015 Volkswagen Golf S 1.8L GAS L4 ',
    '2015 Volkswagen Golf S 2.0L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf S 1.8L GAS L4 ',
    '2015 Volkswagen Golf TDI SE 2.0L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf SE 1.8L GAS L4 ',
    '2015 Volkswagen Golf TDI SEL Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L DIESEL L4 ',
    '2015 Volkswagen Golf TDI SE DIESEL L4 Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf S 2.0L DIESEL L4 ',
    '2015 Volkswagen Golf SE 1.8L GAS L4 ',
    '2015 Volkswagen Golf SE 1.8L GAS L4 ',
    '2015 Volkswagen Golf TDI SE 2.0L DIESEL L4 ',
    '2015 Volkswagen Golf TDI S DIESEL L4 Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL',
    '2015 Volkswagen Golf TDI S 2.0L DIESEL L4 ',
    '2015 Volkswagen Golf S 1.8L GAS L4 ',
    '2015 Volkswagen Golf TDI S DIESEL L4',
    '2015 Volkswagen Golf TDI SEL 1.8L GAS L4 ',
    '2015 Volkswagen Golf Variant 1.4 TSI GAS L4 QRM DSG',
    '2015 Volkswagen Golf TDI SE 1.8L GAS L4 ',
    '2015 Volkswagen Golf S 1.8L L4 GAS Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L GAS L4  Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf S 1.8L GAS L4  Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Comfortline 1.8L GAS L4  Standard 5 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf SE 1.8L L4 GAS Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Golf Highline TDI 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Trendline TDI 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf R 2.0L L4 GAS Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf GTD Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Golf TDI SE 1.8L GAS L4 ',
    '2015 Volkswagen Golf S 1.8L L4 GAS Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L GAS L4  Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf S 1.8L GAS L4  Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Comfortline 1.8L GAS L4  Standard 5 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf SE 1.8L L4 GAS Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Golf Highline TDI 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Trendline TDI 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf R 2.0L L4 GAS Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf GTD Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Automatic Dual Clutch 6',
    '2015 Volkswagen Golf Sportwagen TDI Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf SE 1.8L L4 GAS Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf R 2L GAS L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI 2L DIESEL L4  Standard 6',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen Hatchback (4 Door)',
    '2015 Volkswagen Golf S 1.8L GAS L4 ',
    '2015 Volkswagen Golf Highline 1.8L GAS L4  Standard 5 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Highline 1.4L GAS L4  Automatic Dual Clutch 7 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Sportwagen TDI L4 DIESEL Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L DIESEL L4 ',
    '2015 Volkswagen Golf TDI SEL 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Comfortline 1.4L GAS L4  Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf SE 1.8L GAS L4  Automatic 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2L DIESEL L4  Standard 6',
    '2015 Volkswagen Golf TDI S 2L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf Highline 1.4L GAS L4 ',
    '2015 Volkswagen Golf Sportwagen TDI 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2L DIESEL L4  Standard 6',
    '2015 Volkswagen Golf R 2L GAS L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf SE 2.0L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI S 2.0L L4 DIESEL Standard 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SE 2.0L DIESEL L4  Automatic Dual Clutch 6 Hatchback (4 Door)',
    '2015 Volkswagen Golf TDI SEL 2L DIESEL L4  Standard 6 Hatchback (4 Door)',
    '2015 Toyota Tacoma  4L GAS V6  Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Off-Road 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma Pre Runner 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Off-Road 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Off-Road Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4L GAS V6  Automatic 5',
    '2015 Toyota Tacoma TRD Off-Road Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4L GAS V6  Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Off Road V6',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Standard 6 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Pro 4.0L GAS V6  Automatic 5',
    '2015 Toyota Tacoma TRD Pro 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 4 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  ',
    '2015 Toyota Tacoma TRD Pro 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L V6 GAS Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Pro 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  2.7L L4 GAS Automatic 4 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  2.7L L4 GAS Standard 5',
    '2015 Toyota Tacoma Pre Runner 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Standard 6 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Off-Road 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Pro 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma Pre Runner 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  2.7L GAS L4  Standard 5',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  2.7L GAS L4  Automatic 4 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma Pre Runner 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L V6 GAS Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport ',
    '2015 Toyota Tacoma TRD Off-Road 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L GAS V6  Standard 6 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma limitef ',
    '2015 Toyota Tacoma Pre Runner 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Pro 4.0L GAS V6  Automatic 4 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Off Road GAS V6 Automatic 5 4wd 4-door',
    '2015 Toyota Tacoma Pre Runner 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  2.7L GAS L4  Standard 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma Pre Runner 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Pro 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Pro 4.0L GAS V6  Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  2.7L GAS L4  Standard 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma Pre Runner 2.7L GAS L4  Automatic 4',
    '2015 Toyota Tacoma Pre Runner 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L GAS V6  Automatic 4 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma Pre Runner 2.7L GAS L4  Automatic 4 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  2.7L GAS L4  Standard 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L GAS V6  Standard 6 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L GAS V6  Automatic 4 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L GAS V6  Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L V6 GAS Automatic 5 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  2.7L GAS L4  Standard 5',
    '2015 Toyota Tacoma TRD Sport 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Pro ',
    '2015 Toyota Tacoma  4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Pro 4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  ',
    '2015 Toyota Tacoma  4L GAS V6  Automatic 5',
    '2015 Toyota Tacoma TRD Off Road GAS V6 4x4 Double Cab Short Bed',
    '2015 Toyota Tacoma Pre Runner 4.0L GAS V6  Automatic 4 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L V6 GAS Automatic 4 Extended Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma  4.0L GAS V6  Automatic 4 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4.0L V6 GAS Automatic 5',
    '2015 Toyota Tacoma TRD Sport ',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Sport 4L GAS V6  Automatic 5',
    '2015 Toyota Tacoma TRD Off-Road Crew Cab Pickup (4 Door)',
    '2015 Toyota Tacoma TRD Pro 4.0L V6 GAS Automatic 5 Crew Cab Pickup (4 Door)',
    '2015 Toyota Prius Plug-In 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Persona ',
    '2015 Toyota Prius Three 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Three 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Four 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Four 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L ELECTRIC/GAS L4  Automatic Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L ELECTRIC/GAS L4  Automatic Hatchback (4 Door)',
    '2015 Toyota Prius  ',
    '2015 Toyota Prius Two 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Hybrid T3 Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Three 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Three 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Three 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius  ',
    '2015 Toyota Prius Two 1.8L ELECTRIC/GAS L4  Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L ELECTRIC/GAS L4  Automatic CVT',
    '2015 Toyota Prius Four 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Plug-In Hatchback (4 Door)',
    '2015 Toyota Prius Four 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Five 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Three 1.8L ELECTRIC/GAS L4  Automatic CVT',
    '2015 Toyota Prius Four 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Three 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Five 1.8L ELECTRIC L4  Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two ',
    '2015 Toyota Prius  1.8L ELECTRIC L4  Automatic',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Two 1.8L L4 ELECTRIC/GAS Automatic CVT Hatchback (4 Door)',
    '2015 Toyota Prius Three 1.8L ELECTRIC/GAS L4  Automatic CVT Hatchback (4 Door)',
    ]

# %%
engineRE = re.compile('(\d\.*\d*L).*[FLEX|GAS|DIESEL|CNG]',flags=re.IGNORECASE)

# %%
fuelRE = re.compile('(FLEX|GAS|DIESEL|CNG)',flags=re.IGNORECASE)

# %%
transRE = re.compile('(Automatic.* \d|Standard \d|Automatic CVT)',flags=re.IGNORECASE)

# %%
for t in test:
    print t
    print engineRE.findall(t)
    print fuelRE.findall(t)
    print transRE.findall(t)
    print
# Out:
# 2015 Volkswagen Jetta TDI SE 1.4L ELECTRIC/GAS L4  Standard 5 Sedan (4 Door)
# ['1.4L']
# ['GAS']
# ['Standard 5']
#
# 2015 Volkswagen Jetta TDI SE 2L DIESEL L4  Standard 6 Sedan (4 Door)
# ['2L']
# ['DIESEL']
# ['Standard 6']
#
# 2015 Volkswagen Jetta TDI SE 2L DIESEL L4
# ['2L']
# ['DIESEL']
# []
#
# 2015 Volkswagen Jetta GLI SE 2.0L L4 GAS Standard 6 Sedan (4 Door)
# ['2.0L']
# ['GAS']
# ['Standard 6']
#
# 2015 Volkswagen Jetta S 1.4L ELECTRIC/GAS L4  Standard 6 Sedan (4 Door)
# ['1.4L']
# ['GAS']
# ['Standard 6']
#
# 2015 Volkswagen Jetta TDI SE 2L DIESEL L4
# ['2L']
# ['DIESEL']
# []
#
# 2015 Volkswagen Jetta TDI SEL 2.0L L4 DIESEL Standard 6 Sedan (4 Door)
# ['2.0L']
# ['DIESEL']
# ['Standard 6']
#
# 2015 Volkswagen Jetta TDI 2L DIESEL L4  Standard 6
# ['2L']
# ['DIESEL']
# ['Standard 6']
#
# 2015 Volkswagen Jetta Comfortline TDI 2L DIESEL L4  Standard 6 Sedan (4 Door)
# ['2L']
# ['DIESEL']
# ['Standard 6']
#
# 2015 Volkswagen Jetta TDI 2L DIESEL L4  Standard 6
# ['2L']
# ...

# %%
nationalities = {
	14:'Australia',
	29:'Brazil',
	36:'Canada',
	46:'China',
	86:'Greece',
	99:'Ireland',
	152:'Mexico',
	153:'Maylasia',
	162:'Norway',
	166:'New Zealand',
	179:'Portugal',
	210:'Thailand',
	217:'Turkey',
	220:'Taiwan',
	222:'Ukraine',
	224:'United Kingdom',
	226:'United States',
	241:'South Africa'
	}

# %%
country = int('226')

# %%
nationalities.get(country, country)
# Out:
# 'United States'

# %%
intstr = ' 02,26.123   '

# %%
int(intstr.replace(',','').split('.')[0])
# Out:
# 226

# %%
progressFilename = 'fuellyProgress.txt'
f = open(progressFilename, 'r+')
lastRecord = int(f.readline())
f.close()
print lastRecord
# Out:
# 13

# %%
index = lastRecord
if index <= lastRecord: index+=1
f = open(progressFilename, 'w+')
f.write('%d' % index)
f.close()

# %%
from multiprocessing import Pool
from pyquery import PyQuery as pq

# %%
def worker(thing): 
    print 'working'
    return ['something','asdf']

# %%
pool = Pool(processes=4)
over = [1,2,3,4]
ownerModelInfo = pool.map(worker, over)
print ownerModelInfo
# Out:
# [['something', 'asdf'], ['something', 'asdf'], ['something', 'asdf'], ['something', 'asdf']]
# working
# working
# working
# working
